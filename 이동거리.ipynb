# %% [markdown]
# ### 이동거리

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 이동거리 데이터
distance_16 = pd.read_csv('C:/Users/dudco/Desktop/SVT/distance/distance_2016.csv',encoding='CP949')
distance_17 = pd.read_csv('C:/Users/dudco/Desktop/SVT/distance/distance_2017.csv',encoding='CP949')
distance_18 = pd.read_csv('C:/Users/dudco/Desktop/SVT/distance/distance_2018.csv',encoding='CP949')
distance_19 = pd.read_csv('C:/Users/dudco/Desktop/SVT/distance/distance_2019.csv',encoding='CP949')
distance_20 = pd.read_csv('C:/Users/dudco/Desktop/SVT/distance/distance_2020.csv',encoding='CP949')

# %%
# 팀별 데이터
team_16 = pd.read_csv('C:/Users/dudco/Desktop/SVT/SVT_join_data/team_16.csv',encoding='CP949')
team_17 = pd.read_csv('C:/Users/dudco/Desktop/SVT/SVT_join_data/team_17.csv',encoding='CP949')
team_18 = pd.read_csv('C:/Users/dudco/Desktop/SVT/SVT_join_data/team_18.csv',encoding='CP949')
team_19 = pd.read_csv('C:/Users/dudco/Desktop/SVT/SVT_join_data/team_19.csv',encoding='CP949')
team_20 = pd.read_csv('C:/Users/dudco/Desktop/SVT/SVT_join_data/team_20.csv',encoding='CP949')
team_16
# Out:
#       Unnamed: 0           G_ID   GDAY_DS T_ID VS_T_ID  HEADER_NO TB_SC  \
# 0              0  20160401HHLG0  20160401   LG      HH          0     B
# 1              1  20160401HHLG0  20160401   HH      LG          0     T
# 2              2  20160401HTNC0  20160401   NC      HT          0     B
# 3              3  20160401HTNC0  20160401   HT      NC          0     T
# 4              4  20160401KTSK0  20160401   SK      KT          0     B
# ...          ...            ...       ...  ...     ...        ...   ...
# 1435        1435  20161008SSSK0  20161008   SS      SK          0     T
# 1436        1436  20161009KTNC0  20161009   NC      KT          0     B
# 1437        1437  20161009KTNC0  20161009   KT      NC          0     T
# 1438        1438  20161009WOLT0  20161009   LT      WO          0     B
# 1439        1439  20161009WOLT0  20161009   WO      LT          0     T
#
#       CG_CK WLS  HOLD  ...  GD  H_ERR  LOB  P_HRA_RT  P_AB_CN  P_HIT_CN  \
# ...

# %%
# 조인 기준 키 만들기
team_16['KEY'] = team_16['T_ID']+team_16['VS_T_ID'] 
team_17['KEY'] = team_17['T_ID']+team_17['VS_T_ID'] 
team_18['KEY'] = team_18['T_ID']+team_18['VS_T_ID'] 
team_19['KEY'] = team_19['T_ID']+team_19['VS_T_ID'] 
team_20['KEY'] = team_20['T_ID']+team_20['VS_T_ID'] 
team_16
# Out:
#       Unnamed: 0           G_ID   GDAY_DS T_ID VS_T_ID  HEADER_NO TB_SC  \
# 0              0  20160401HHLG0  20160401   LG      HH          0     B
# 1              1  20160401HHLG0  20160401   HH      LG          0     T
# 2              2  20160401HTNC0  20160401   NC      HT          0     B
# 3              3  20160401HTNC0  20160401   HT      NC          0     T
# 4              4  20160401KTSK0  20160401   SK      KT          0     B
# ...          ...            ...       ...  ...     ...        ...   ...
# 1435        1435  20161008SSSK0  20161008   SS      SK          0     T
# 1436        1436  20161009KTNC0  20161009   NC      KT          0     B
# 1437        1437  20161009KTNC0  20161009   KT      NC          0     T
# 1438        1438  20161009WOLT0  20161009   LT      WO          0     B
# 1439        1439  20161009WOLT0  20161009   WO      LT          0     T
#
#       CG_CK WLS  HOLD  ...  H_ERR  LOB  P_HRA_RT  P_AB_CN  P_HIT_CN  \
# ...

# %%
# 조인 (이동거리+ 팀 데이터)
dt_16 = pd.merge(team_16, distance_16, on=['KEY', 'STADIUM'], how='inner')
dt_17 = pd.merge(team_17, distance_17, on=['KEY', 'STADIUM'], how='inner')
dt_18 = pd.merge(team_18, distance_18, on=['KEY', 'STADIUM'], how='inner')
dt_19 = pd.merge(team_19, distance_19, on=['KEY', 'STADIUM'], how='inner')
dt_20 = pd.merge(team_20, distance_20, on=['KEY', 'STADIUM'], how='inner')

# %%
dt_16
# Out:
#       Unnamed: 0           G_ID   GDAY_DS T_ID VS_T_ID  HEADER_NO TB_SC  \
# 0              0  20160401HHLG0  20160401   LG      HH          0     B
# 1             10  20160402HHLG0  20160402   LG      HH          0     B
# 2            790  20160712HHLG0  20160712   LG      HH          0     B
# 3            800  20160713HHLG0  20160713   LG      HH          0     B
# 4            810  20160714HHLG0  20160714   LG      HH          0     B
# ...          ...            ...       ...  ...     ...        ...   ...
# 1467        1061  20160817OBHH0  20160817   OB      HH          0     T
# 1468        1108  20160823KTLT0  20160823   LT      KT          0     B
# 1469        1116  20160824KTLT0  20160824   LT      KT          0     B
# 1470        1109  20160823KTLT0  20160823   KT      LT          0     T
# 1471        1117  20160824KTLT0  20160824   KT      LT          0     T
#
#       CG_CK WLS  HOLD  ...  LOB  P_HRA_RT  P_AB_CN  P_HIT_CN  VISIT_KEY  \
# ...

# %% [markdown]
# ### 날씨

# %%
# 날씨 데이터
weather_16 = pd.read_csv('C:/Users/dudco/Desktop/SVT/weather/2016_weather.csv',encoding='CP949')
weather_17 = pd.read_csv('C:/Users/dudco/Desktop/SVT/weather/2017_weather.csv',encoding='CP949')
weather_18 = pd.read_csv('C:/Users/dudco/Desktop/SVT/weather/2018_weather.csv',encoding='CP949')
weather_19 = pd.read_csv('C:/Users/dudco/Desktop/SVT/weather/2019_weather.csv',encoding='CP949')
weather_20 = pd.read_csv('C:/Users/dudco/Desktop/SVT/weather/2020_weather.csv',encoding='CP949')

# %%
weather_16.loc[weather_16['지점명']=='창원','지점명']='마산'
weather_17.loc[weather_17['지점명']=='창원','지점명']='마산'
weather_18.loc[weather_18['지점명']=='창원','지점명']='마산'

# %%
weather_16=weather_16.rename({'지점명':'STADIUM','일시':'GDAY_DS'},axis='columns')
weather_17=weather_17.rename({'지점명':'STADIUM','일시':'GDAY_DS'},axis='columns')
weather_18=weather_18.rename({'지점명':'STADIUM','일시':'GDAY_DS'},axis='columns')
weather_19=weather_19.rename({'지점명':'STADIUM','일시':'GDAY_DS'},axis='columns')
weather_20=weather_20.rename({'지점명':'STADIUM','일시':'GDAY_DS'},axis='columns')

# %%
weather_16=weather_16.fillna(0)
weather_17=weather_17.fillna(0)
weather_18=weather_18.fillna(0)
weather_19=weather_19.fillna(0)
weather_20=weather_20.fillna(0)

# %%
weather_16.describe()
# Out:
#                지점       GDAY_DS         평균기온         최저기온         최고기온  \
# count  2304.00000  2.304000e+03  2304.000000  2304.000000  2304.000000
# mean    134.50000  2.016068e+07    22.100000    18.181554    26.873003
# std      18.35019  1.811659e+02     4.900195     5.425979     4.995577
# min     108.00000  2.016040e+07     8.100000     4.000000    11.300000
# 25%     117.25000  2.016052e+07    19.175000    14.300000    23.675000
# 50%     135.50000  2.016071e+07    22.500000    19.000000    27.100000
# 75%     152.75000  2.016082e+07    25.400000    22.100000    30.300000
# max     159.00000  2.016101e+07    32.800000    28.700000    39.300000
#
#               일강수량     최대 순간 풍속  최대 순간 풍속 풍향        최대 풍속     최대 풍속 풍향  \
# count  2304.000000  2304.000000  2304.000000  2304.000000  2304.000000
# mean      5.374392     7.924870   196.827257     4.725130   194.396701
# std      17.235620     2.635512    97.857436     1.579204    95.662240
# ...

# %%
t_16 = pd.merge(weather_16, dt_16, on=['GDAY_DS', 'STADIUM'], how='right')
t_17 = pd.merge(weather_17, dt_17, on=['GDAY_DS', 'STADIUM'], how='right')
t_18 = pd.merge(weather_18, dt_18, on=['GDAY_DS', 'STADIUM'], how='right')
t_19 = pd.merge(weather_19, dt_19, on=['GDAY_DS', 'STADIUM'], how='right')
t_20 = pd.merge(weather_20, dt_20, on=['GDAY_DS', 'STADIUM'], how='right')

# %%
t_16
# Out:
#        지점 STADIUM   GDAY_DS  평균기온  최저기온  최저기온 시각  최고기온  최고기온 시각  10분 최다 강수량  \
# 0     108      고척  20160401  15.3   7.3      625  23.8     1333         NaN
# 1     108      고척  20160401  15.3   7.3      625  23.8     1333         NaN
# 2     112      문학  20160401  13.5   8.3      704  19.7     1328         NaN
# 3     112      문학  20160401  13.5   8.3      704  19.7     1328         NaN
# 4     143      대구  20160401  14.4   5.6      510  23.2     1412         NaN
# ...   ...     ...       ...   ...   ...      ...   ...      ...         ...
# 1467  108      잠실  20161008  16.8  10.3     2357  21.8     1410         0.5
# 1468  155      마산  20161009  14.7  12.1     2357  19.4     1457         NaN
# 1469  155      마산  20161009  14.7  12.1     2357  19.4     1457         NaN
# 1470  159      사직  20161009  16.2  13.1      638  22.0     1258         NaN
# 1471  159      사직  20161009  16.2  13.1      638  22.0     1258         NaN
#
# ...

# %% [markdown]
# ### 이동거리 범주형으로 만들기

# %%
distance_16['DISTANCE'] =distance_16['DISTANCE'].astype('int')
distance_17['DISTANCE'] =distance_17['DISTANCE'].astype('int')
distance_18['DISTANCE'] =distance_18['DISTANCE'].astype('int')
distance_19['DISTANCE'] =distance_19['DISTANCE'].astype('int')
distance_20['DISTANCE'] =distance_20['DISTANCE'].astype('int')

# %%
DISTANCElist=[
    (dt_16['DISTANCE']< 1),
    (dt_16['DISTANCE']>=1) & (dt_16['DISTANCE']<50),
    (dt_16['DISTANCE']>=50) & (dt_16['DISTANCE']<100),
    (dt_16['DISTANCE']>=100)
]
choicelist =[0,1,2,3]
dt_16['DT']=np.select(DISTANCElist, choicelist)

# %%
DISTANCElist=[
    (dt_17['DISTANCE']< 1),
    (dt_17['DISTANCE']>=1) & (dt_17['DISTANCE']<50),
    (dt_17['DISTANCE']>=50) & (dt_17['DISTANCE']<100),
    (dt_17['DISTANCE']>=100)
]
choicelist =[0,1,2,3]
dt_17['DT']=np.select(DISTANCElist, choicelist)

# %%
DISTANCElist=[
    (dt_18['DISTANCE']< 1),
    (dt_18['DISTANCE']>=1) & (dt_18['DISTANCE']<50),
    (dt_18['DISTANCE']>=50) & (dt_18['DISTANCE']<100),
    (dt_18['DISTANCE']>=100)
]
choicelist =[0,1,2,3]
dt_18['DT']=np.select(DISTANCElist, choicelist)

# %%
DISTANCElist=[
    (dt_19['DISTANCE']< 1),
    (dt_19['DISTANCE']>=1) & (dt_19['DISTANCE']<50),
    (dt_19['DISTANCE']>=50) & (dt_19['DISTANCE']<100),
    (dt_19['DISTANCE']>=100)
]
choicelist =[0,1,2,3]
dt_19['DT']=np.select(DISTANCElist, choicelist)

# %%
DISTANCElist=[
    (dt_20['DISTANCE']< 1),
    (dt_20['DISTANCE']>=1) & (dt_20['DISTANCE']<50),
    (dt_20['DISTANCE']>=50) & (dt_20['DISTANCE']<100),
    (dt_20['DISTANCE']>=100)
]
choicelist =[0,1,2,3]
dt_20['DT']=np.select(DISTANCElist, choicelist)

# %%
dt_16
# Out:
#       Unnamed: 0           G_ID   GDAY_DS T_ID VS_T_ID  HEADER_NO TB_SC  \
# 0              0  20160401HHLG0  20160401   LG      HH          0     B
# 1             10  20160402HHLG0  20160402   LG      HH          0     B
# 2            790  20160712HHLG0  20160712   LG      HH          0     B
# 3            800  20160713HHLG0  20160713   LG      HH          0     B
# 4            810  20160714HHLG0  20160714   LG      HH          0     B
# ...          ...            ...       ...  ...     ...        ...   ...
# 1467        1061  20160817OBHH0  20160817   OB      HH          0     T
# 1468        1108  20160823KTLT0  20160823   LT      KT          0     B
# 1469        1116  20160824KTLT0  20160824   LT      KT          0     B
# 1470        1109  20160823KTLT0  20160823   KT      LT          0     T
# 1471        1117  20160824KTLT0  20160824   KT      LT          0     T
#
#       CG_CK WLS  HOLD  ...  P_HRA_RT  P_AB_CN  P_HIT_CN  VISIT_KEY  HOME_KEY  \
# ...

# %%
dt_16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1472 entries, 0 to 1471
# Data columns (total 64 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1472 non-null   int64
#  1   G_ID        1472 non-null   object
#  2   GDAY_DS     1472 non-null   int64
#  3   T_ID        1472 non-null   object
#  4   VS_T_ID     1472 non-null   object
#  5   HEADER_NO   1472 non-null   int64
#  6   TB_SC       1472 non-null   object
#  7   CG_CK       1472 non-null   int64
#  8   WLS         1472 non-null   object
#  9   HOLD        1472 non-null   int64
#  10  INN2        1472 non-null   int64
#  11  BF          1472 non-null   int64
#  12  VS_PA       1472 non-null   int64
#  13  VS_AB       1472 non-null   int64
#  14  VS_HIT      1472 non-null   int64
#  15  VS_H2       1472 non-null   int64
#  16  VS_H3       1472 non-null   int64
#  17  VS_HR       1472 non-null   int64
#  18  VS_SB       1472 non-null   int64
# ...

# %% [markdown]
# ### 이동거리별 승패

# %%
pd.crosstab(dt_16.DT,dt_16.WLS)
# Out:
# WLS  D    L    W
# DT
# 0    7  347  397
# 1    1   79   70
# 2    0   32   24
# 3    6  271  238

# %%
pd.crosstab(dt_16.DT, dt_16.WLS).plot(kind='bar')

# %%
pd.crosstab(dt_17.DT, dt_17.WLS).plot(kind='bar')

# %%
pd.crosstab(dt_18.DT, dt_18.WLS).plot(kind='bar')

# %%
pd.crosstab(dt_19.DT, dt_19.WLS).plot(kind='bar')

# %%
pd.crosstab(dt_20.DT, dt_20.WLS).plot(kind='bar')
