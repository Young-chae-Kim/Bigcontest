# %% [markdown]
# ## 안타 모델

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
team = pd.read_csv('C:/Users/dudco/Desktop/SVT_code/team.csv', encoding='CP949')

# %%
team.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6400 entries, 0 to 6399
# Data columns (total 61 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  6400 non-null   int64
#  1   G_ID        6400 non-null   object
#  2   GDAY_DS     6400 non-null   int64
#  3   T_ID        6400 non-null   object
#  4   VS_T_ID     6400 non-null   object
#  5   HEADER_NO   6400 non-null   int64
#  6   TB_SC       6400 non-null   object
#  7   CG_CK       6400 non-null   int64
#  8   WLS         6400 non-null   object
#  9   HOLD        6400 non-null   int64
#  10  INN2        6400 non-null   int64
#  11  BF          6400 non-null   int64
#  12  VS_PA       6400 non-null   int64
#  13  VS_AB       6400 non-null   int64
#  14  VS_HIT      6400 non-null   int64
#  15  VS_H2       6400 non-null   int64
#  16  VS_H3       6400 non-null   int64
#  17  VS_HR       6400 non-null   int64
#  18  VS_SB       6400 non-null   int64
# ...

# %%
team.describe()
# Out:
#         Unnamed: 0       GDAY_DS    HEADER_NO        CG_CK         HOLD  \
# count  6400.000000  6.400000e+03  6400.000000  6400.000000  6400.000000
# mean   3199.500000  2.017815e+07     0.009375     0.013437     0.406719
# std    1847.665193  1.297423e+04     0.124658     0.115148     0.776502
# min       0.000000  2.016040e+07     0.000000     0.000000     0.000000
# 25%    1599.750000  2.017042e+07     0.000000     0.000000     0.000000
# 50%    3199.500000  2.018050e+07     0.000000     0.000000     0.000000
# 75%    4799.250000  2.019052e+07     0.000000     0.000000     1.000000
# max    6399.000000  2.020072e+07     2.000000     1.000000     5.000000
#
#               INN2           BF        VS_PA        VS_AB       VS_HIT  ...  \
# count  6400.000000  6400.000000  6400.000000  6400.000000  6400.000000  ...
# mean     26.628750   151.882656    39.376562    34.759062     9.780938  ...
# std       2.172291    23.894167     5.280009     4.297327     3.750103  ...
# ...

# %% [markdown]
# ### AVG (타율)

# %%
team['AVG']=team['HIT']/team['AB']
team['AVG']
# Out:
# 0       0.214286
# 1       0.282609
# 2       0.300000
# 3       0.235294
# 4       0.277778
#           ...
# 6395    0.206897
# 6396    0.250000
# 6397    0.297297
# 6398    0.200000
# 6399    0.212121
# Name: AVG, Length: 6400, dtype: float64

# %% [markdown]
# ### OBP (출루율)

# %%
team['OBP']=(team['HIT']+team['BB']+team['HP'])/(team['AB']+team['BB']+team['HP']+team['SF'])
team['OBP']
# Out:
# 0       0.282609
# 1       0.326531
# 2       0.400000
# 3       0.315789
# 4       0.277778
#           ...
# 6395    0.233333
# 6396    0.368421
# 6397    0.365854
# 6398    0.351351
# 6399    0.297297
# Name: OBP, Length: 6400, dtype: float64

# %% [markdown]
# ### H1 (1루타)

# %%
team['H1']=team['HIT']-team['H2']-team['H3']-team['HR']
team['H1']
# Out:
# 0        6
# 1       11
# 2        5
# 3        4
# 4        4
#         ..
# 6395     4
# 6396     7
# 6397     7
# 6398     6
# 6399     6
# Name: H1, Length: 6400, dtype: int64

# %% [markdown]
# ### SLG (장타율)

# %%
team
